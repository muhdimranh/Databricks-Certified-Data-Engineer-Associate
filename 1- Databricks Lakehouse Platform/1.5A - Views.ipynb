# %%
# %sql
USE CATALOG hive_metastore;

CREATE TABLE IF NOT EXISTS smartphones
(id INT, name STRING, brand STRING, year INT);

INSERT INTO smartphones
VALUES 
  (1, 'iPhone 14', 'Apple', 2022),
  (2, 'iPhone 13', 'Apple', 2021),
  (3, 'iPhone 6', 'Apple', 2014),
  (4, 'Galaxy S22', 'Samsung', 2022),
  (5, 'Galaxy S9', 'Samsung', 2016),
  (6, '12 Pro', 'Xiaomi', 2022);

# %%
display(dbutils.fs.ls('dbfs:/user/hive/warehouse/smartphones'))

# %%
# %sql
DROP VIEW apple_phones

# %%
# %sql
CREATE VIEW view_apple_phones
AS SELECT * FROM smartphones WHERE brand = 'Apple'

# %%
# %sql SHOW VIEWS

# %%
# %sql
CREATE TEMP VIEW temp_view_phone_brands
AS SELECT DISTINCT brand FROM smartphones

# %%
# %sql
SHOW VIEWS

# %%
# %sql
CREATE GLOBAL TEMP VIEW global_temp_view_phone_2020
AS SELECT * FROM smartphones WHERE year >= 2020

# %%
# %sql 
SHOW TABLES IN global_temp

# %%
# %sql
SELECT * FROM global_temp.global_temp_view_phone_2020
