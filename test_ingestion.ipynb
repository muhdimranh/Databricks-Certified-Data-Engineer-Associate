# %%
# %run ./Includes/Copy-Datasets

# %%
display(dbutils.fs.ls('dbfs:/mnt/demo-datasets/bookstore/books-csv'))

# %%
# %sql
DROP TABLE databricks_demo.demo.books

# %%
# %sql
DROP TABLE IF EXISTS books_test

# %%
csv_path = f"{dataset_bookstore}/books-csv/export*.csv"

df = spark.read.option("header", True).option("delimiter", ";").option("inferSchema", True).csv(csv_path)

# %%
display(df)

# %%
df.write.format("delta").mode('overwrite').save("dbfs:/delta/books_test")

# %%
df.write.format("delta").mode('overwrite').option("path", "dbfs:/delta/books_test").saveAsTable("books_test")

# %%
spark.sql("""
    CREATE TABLE IF NOT EXISTS books_test
    LOCATION 'dbfs:/delta/books_test'
""")

# %%
# %sql
SELECT * FROM books_test

# %%
# %sql
INSERT INTO books_test (book_id, title)
VALUES ("B100", "Test Book")

# %%
# %sql DESCRIBE HISTORY books_test

# %%
# %sql
RESTORE TABLE books_test TO VERSION AS OF 7

# %%
# %sql DESCRIBE EXTENDED books_test

# %%
dbutils.fs.rm("")
