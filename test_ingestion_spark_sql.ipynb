# %%
# %run ./Includes/Copy-Datasets

# %%
display(dbutils.fs.ls(f'{dataset_bookstore}/books-csv/'))

# %%
csv_path = f'{dataset_bookstore}/books-csv/export*.csv'
print(csv_path)

# %%
# %sql
CREATE OR REPLACE TEMP VIEW temp_view_books
USING CSV
OPTIONS (
  header = true
  ,delimiter = ";"
  ,path = '${dataset.bookstore}/books-csv/export*.csv'
  ,inferSchema = true
)

# %%
# %sql
SELECT * FROM temp_view_books

# %%
# %sql
DROP TABLE IF EXISTS books_test_sql;
CREATE OR REPLACE TABLE books_test_sql
  -- (book_id STRING, title STRING, author STRING, category STRING, price DOUBLE)
-- LOCATION 'dbfs:/test'
AS SELECT * FROM temp_view_books

# %%
# %sql
SELECT * FROM books_test_sql

# %%
# %sql
DESCRIBE EXTENDED books_test_sql

# %%
# %sql
DROP TABLE books_test_sql

# %%
dbutils.fs.rm('dbfs:/test', recurse=True)

# %%
dbutils.fs.ls('/')

# %%
# %sql
CREATE TABLE test22
LOCATION 'dbfs:/test22'

# %%
# %sql
DROP TABLE test22

# %%
dbutils.fs.rm('dbfs:/test55', recurse=True)

# %%
# %sql
CREATE TABLE test23
LOCATION 'dbfs:/test'

# %%
# %sql
DROP TABLE test24

# %%
# %sql
CREATE TABLE test24
LOCATION 'dbfs:/user/hive/warehouse/books_test_sql'
AS SELECT * FROM temp_view_books

# %%
display(dbutils.fs.ls('dbfs:/test55'))
